# %% [markdown]
# # Bioactivity prediction

# %% [markdown]
# > In this notebook we use the image representations of the data sets in https://link.springer.com/article/10.1186/s13321-017-0226-y as created in `dev-notebooks/DL-Example-3-get_molecular_fingerprints_and_images.ipynb`. To successfully run this notebook you'll have to first run the notebook linked above. It'll download the raw data and prepare the images.

# %% [markdown]
# <img width=60% src="assets/MOESM-paper.png">

# %% [markdown]
# # Setup

# %%
# This is a quick check of whether the notebook is currently running on Google Colaboratory, as that makes some difference for the code below.
# We'll do this in every notebook of the course.
if 'google.colab' in str(get_ipython()):
    print('The notebook is running on Colab. colab=True.')
    colab=True
else:
    print('The notebook is not running on Colab. colab=False.')
    colab=False
# Out:
# The notebook is not running on Colab. colab=False.

# %%
gradient=False

# %%
# %matplotlib inline
import pandas as pd, numpy as np
from pathlib import Path
import gc

# %%
NB_DIR = Path.cwd()

DATA = NB_DIR/'dev-notebooks'/'data'/'drug'
RAWDATA = DATA/'raw'
INTERIMDATA = DATA/'interim'

if gradient:
    IMGDATA = Path('/storage/molimages')
else:
    # Path to image data as defined earlier
    IMGDATA = Path('/data2/alex/pcs-data/drug/molimages')

# %%
if colab or gradient:
    # !pip install -Uqq fastbook
    import fastbook
    fastbook.setup_book()
    from fastbook import *
    # !pip install fastai-amalgam
    # !pip install palettable
    # !pip install matplotlib_venn
    from fastai.vision.all import *

# %%
from fastai.vision.all import *

# %%
chembl_to_dataset = {
    
    'CHEMBL205': 'CAII',
    'CHEMBL301': 'CDK2',
    'CHEMBL240': 'HERG',
    'CHEMBL219': 'DRD4',
    'CHEMBL244': 'CogX',
    'CHEMBL218': 'CB1',
    'CHEMBL1978': 'CYP_19A1'}

# %%
top_mcc_scores = {
    
    'CHEMBL205': 0.862,
    'CHEMBL301': 0.926,
    'CHEMBL240': 0.884,
    'CHEMBL219': 0.887,
    'CHEMBL244': 0.983,
    'CHEMBL218': 0.941,
    'CHEMBL1978': 0.904}

# %% [markdown]
# 1. CHEMBL205: Carbonic Anhydrase II, a protein lyase
# 2. CHEMBL301: Cyclin-dependent kinase 2, a protein kinase
# 3. CHEMNL240: ether-a-go-go-related gene potassium channel 1 (HERG)
# 4. CHEMBL219: Dopamine D4 receptor, a monoamine GPCR
# 5. CHEMBL244: Coagulation factor X, a serine protease
# 6. CHEMBL218: Cannabinoid CB1 receptor, a lipid-like GPCR
# 7. CHEMBL1978: Cytochrome P450 19A1, a cytochrome P450

# %% [markdown]
# # Load data

# %%
# Datasets available:
ds = sorted(list(RAWDATA.glob('CHEM*cl.csv')))

# %%
ds
# Out:
# [Path('/home/ubuntu/Dropbox/medGPU-alex/PCS956-DL-2021/2-intro_to_practical_dl/dev-notebooks/data/drug/raw/CHEMBL1978_cl.csv'),
#  Path('/home/ubuntu/Dropbox/medGPU-alex/PCS956-DL-2021/2-intro_to_practical_dl/dev-notebooks/data/drug/raw/CHEMBL205_cl.csv'),
#  Path('/home/ubuntu/Dropbox/medGPU-alex/PCS956-DL-2021/2-intro_to_practical_dl/dev-notebooks/data/drug/raw/CHEMBL218_cl.csv'),
#  Path('/home/ubuntu/Dropbox/medGPU-alex/PCS956-DL-2021/2-intro_to_practical_dl/dev-notebooks/data/drug/raw/CHEMBL219_cl.csv'),
#  Path('/home/ubuntu/Dropbox/medGPU-alex/PCS956-DL-2021/2-intro_to_practical_dl/dev-notebooks/data/drug/raw/CHEMBL240_cl.csv'),
#  Path('/home/ubuntu/Dropbox/medGPU-alex/PCS956-DL-2021/2-intro_to_practical_dl/dev-notebooks/data/drug/raw/CHEMBL244_cl.csv'),
#  Path('/home/ubuntu/Dropbox/medGPU-alex/PCS956-DL-2021/2-intro_to_practical_dl/dev-notebooks/data/drug/raw/CHEMBL301_cl.csv')]

# %%
IMGDATA.ls()
# Out:
# (#7) [Path('/data2/alex/pcs-data/drug/molimages/CHEMBL219_cl'),Path('/data2/alex/pcs-data/drug/molimages/CHEMBL205_cl'),Path('/data2/alex/pcs-data/drug/molimages/CHEMBL301_cl'),Path('/data2/alex/pcs-data/drug/molimages/CHEMBL244_cl'),Path('/data2/alex/pcs-data/drug/molimages/CHEMBL1978_cl'),Path('/data2/alex/pcs-data/drug/molimages/CHEMBL218_cl'),Path('/data2/alex/pcs-data/drug/molimages/CHEMBL240_cl')]

# %%
def get_df(data):
    """
    Construct a dataframe containing 
        CID, SMILES, Image, Activity
    """
    
    name = data.stem
    
    df = pd.read_csv(data)
    df['Image'] = df['CID'].apply(lambda x: f'{str(x)}.png')
    
    df = df[['CID', 'SMILES', 'Image', 'Activity']]
    
    return df, name

# %%
def explore_dataset(data, plot=False):

    df, name = get_df(data)
    decoys, actives = df['Activity'].value_counts()
    data_name = chembl_to_dataset[name.split("_")[0]]
    score = top_mcc_scores[name.split("_")[0]]
    
    
    print(f"Data set is {name}, {data_name}")
    print(f"MCC top score was {score}")
    print(f"It consists of {len(df)} molecules")
    print(f"There are {decoys} decoys and {actives} actives")
    if plot:
        dls = ImageDataLoaders.from_df(df, path=IMGDATA/name, label_col='Activity', fn_col='Image', bs=32)
        dls.show_batch(nrows=2, ncols=2, max_n=32)
        plt.show()
        # Free up GPU memory after plotting:
        dls=None
        gc.collect()
        torch.cuda.empty_cache()

# %%
for data in ds:
    explore_dataset(data, plot=True)
    print("#"*40)
    print()
# Out:
# Data set is CHEMBL1978_cl, CYP_19A1
# MCC top score was 0.904
# It consists of 6831 molecules
# There are 6210 decoys and 621 actives
# ########################################
#
# Data set is CHEMBL205_cl, CAII
# MCC top score was 0.862
# It consists of 17941 molecules
# There are 16310 decoys and 1631 actives
# ########################################
#
# Data set is CHEMBL218_cl, CB1
# MCC top score was 0.941
# It consists of 20924 molecules
# There are 19013 decoys and 1911 actives
# ########################################
#
# Data set is CHEMBL219_cl, DRD4
# MCC top score was 0.887
# It consists of 5566 molecules
# There are 5060 decoys and 506 actives
# ########################################
#
# Data set is CHEMBL240_cl, HERG
# MCC top score was 0.884
# It consists of 7700 molecules
# There are 7000 decoys and 700 actives
# ########################################
#
# Data set is CHEMBL244_cl, CogX
# MCC top score was 0.983
# It consists of 12584 molecules
# There are 11440 decoys and 1144 actives
# ########################################
#
# Data set is CHEMBL301_cl, CDK2
# MCC top score was 0.926
# It consists of 7755 molecules
# There are 7050 decoys and 705 actives
# ########################################

# %%
df, name = get_df(ds[0])

# %%
name
# Out:
# 'CHEMBL1978_cl'

# %%
df.head()
# Out:
#              CID                                 SMILES              Image  \
# 0  CHEMBL1454842            s1nc(nc1-c1ccncc1)-c1ccncc1  CHEMBL1454842.png
# 1  CHEMBL1939366            s1nc(nc1-c1cccnc1)-c1cccnc1  CHEMBL1939366.png
# 2   CHEMBL192155         s1cncc1\C=C\1/CCc2cc(OC)ccc/12   CHEMBL192155.png
# 3   CHEMBL517816  s1cccc1CN(n1ncnc1)Cc1ccc(cc1)C(C)(C)C   CHEMBL517816.png
# 4   CHEMBL523973  s1cccc1CN(n1ccnc1)Cc1ccc(cc1)C(C)(C)C   CHEMBL523973.png
#
#    Activity
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6831 entries, 0 to 6830
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CID       6831 non-null   object
#  1   SMILES    6831 non-null   object
#  2   Image     6831 non-null   object
#  3   Activity  6831 non-null   int64
# dtypes: int64(1), object(3)
# memory usage: 213.6+ KB

# %%
df['Activity'].value_counts()
# Out:
# 0    6210
# 1     621
# Name: Activity, dtype: int64

# %% [markdown]
# # Create train-val-split and oversample train

# %% [markdown]
# > **TMP:** Oversampling active molecules by duplicating in data frame. Fix: better do it by weights in the dataloader, to save compute and memory.

# %%
df, name = get_df(ds[0])

# %%
from sklearn.model_selection import train_test_split

# %%
def val_cols_and_oversample(df, test_size=0.25, random_state=42, oversample=True):
    x_train,x_val = train_test_split(df.index, test_size=test_size, stratify=df['Activity'], 
                                     random_state=random_state)
    
    df.loc[x_train, 'is_valid']=False
    df.loc[x_val, 'is_valid']=True
    # Oversample is_valid=False columns
    if oversample:
        df = pd.concat([*[df.loc[(df.is_valid==False) & (df.Activity==1)]]*10, 
                        *[df.loc[(df.is_valid==False) & (df.Activity==0)]], 
                        df.loc[df.is_valid==True]], 
                       ignore_index=True)
    return df

# %% [markdown]
# # Create dataloader

# %%
def get_dataloader(dataset, oversample=False, random_state=42, test_size=0.25, 
                   bs=64, batch_tfms=None):
    
    
    # Get the data set as a df, and also the name
    df, name = get_df(dataset)
    
    print(f"Creating a dataloader for the dataset {name}")
    print(f"Settings: oversample={oversample}, random_state={random_state}, test_size={test_size}, batch size={bs}")
    
    # Create is_valid column and oversample
    df = val_cols_and_oversample(df, oversample=oversample, 
                                 test_size=test_size, random_state=random_state)
    
    # Create a datablock
    datablock = DataBlock(
        blocks=(ImageBlock(), CategoryBlock()),
        get_x=ColReader('Image', pref=IMGDATA/name),
        get_y=ColReader('Activity'),
        splitter=ColSplitter('is_valid'),
        item_tfms=None,
        batch_tfms=batch_tfms
        )
    
    # Create a dataloader
    dl = datablock.dataloaders(df, bs=bs, shuffle_train=True)
    
    print("DONE")
    return dl

# %% [markdown]
# For data augmentation, we rotate the images slightly. We also normalize them to have the same intensity stats as the images in the ImageNet data set. This is because we'll use models pretrained on ImageNet data:

# %%
batch_tfms = [Rotate(max_deg=25, pad_mode='border'), 
              Normalize.from_stats(*imagenet_stats)]

# %%
dl = get_dataloader(ds[0], 
                    oversample=True, 
                    random_state=42,
                    batch_tfms=batch_tfms)
# Out:
# Creating a dataloader for the dataset CHEMBL1978_cl
# Settings: oversample=True, random_state=42, test_size=0.25, batch size=64
# DONE

# %%
dl.show_batch()

# %% [markdown]
# One should always have a look at the transformations performed for data augmentation. Figuring out which transformations makes sense, and which doesn't, can sometimes be difficult, requiring domain knowledge. In a given situation one may also come up with novel, tailor-made transformations.
#
# Data augmentation is both a way to expand the training data set (as long as the labels on the transformed data stays the same as the original), and a way to make the model more invariant to the defined transformations.

# %%
dl.show_batch(unique=True)

# %% [markdown]
# # Train

# %%
# Copied from here: https://forums.fast.ai/t/plotting-metrics-after-learning/69937/3
@patch
@delegates(subplots)
def plot_metrics(self: Recorder, nrows=None, ncols=None, figsize=None, endnames=-1, **kwargs):
    metrics = np.stack(self.values)
    names = self.metric_names[1:endnames]
    n = len(names) - 1
    if nrows is None and ncols is None:
        nrows = int(math.sqrt(n))
        ncols = int(np.ceil(n / nrows))
    elif nrows is None: nrows = int(np.ceil(n / ncols))
    elif ncols is None: ncols = int(np.ceil(n / nrows))
    figsize = figsize or (ncols * 6, nrows * 4)
    fig, axs = subplots(nrows, ncols, figsize=figsize, **kwargs)
    axs = [ax if i < n else ax.set_axis_off() for i, ax in enumerate(axs.flatten())][:n]
    for i, (name, ax) in enumerate(zip(names, [axs[0]] + axs)):
        ax.plot(metrics[:, i], color='#1f77b4' if i == 0 else '#ff7f0e', label='valid' if i > 0 else 'train')
        ax.set_title(name if i > 1 else 'losses')
        ax.legend(loc='best')
    plt.show()

# %%
def train_model(dl, arch=resnet18, pretrained=True, epochs=10, wd=2e-4, ps=0.8):
    
    print(f"Training a model on the provided data\n")
    print(f"### Architecture: arch={arch} ###")
    print(f"\t pretrained={pretrained}, epochs={epochs}\n")
    print(f"### Regularization: weight decay={wd}, droput rate={ps} ### \n")
    
    # Create learner
    learn = cnn_learner(
        dl,                             
        arch=arch, pretrained=pretrained,   
        wd=wd, ps=ps,                       
        metrics=[accuracy,                  
                 F1Score(), 
                 Precision(), 
                 Recall(), 
                 RocAucBinary(), 
                 MatthewsCorrCoef()],
        cbs=[ShowGraphCallback()])
    
    print(f"Finding a learning rate...")
    lr = learn.lr_find(show_plot=False)
    
    print(f"Using the base learning rate lr={lr.valley}\n")
    
    print(f"### Training the model... ### \n")
    
    if pretrained:
        learn.freeze()
        learn.fit(1, lr.valley)
    learn.unfreeze()
    learn.fit_one_cycle(epochs, slice(lr.valley))
    
    return learn

# %% [markdown]
# ## Train on a sample data set: `CHEMBL1978`

# %%
ds[0]
# Out:
# Path('/home/ubuntu/Dropbox/medGPU-alex/PCS956-DL-2021/2-intro_to_practical_dl/dev-notebooks/data/drug/raw/CHEMBL1978_cl.csv')

# %%
dl = get_dataloader(ds[0], 
                    oversample=True, 
                    random_state=42,
                    batch_tfms=batch_tfms)
# Out:
# Creating a dataloader for the dataset CHEMBL1978_cl
# Settings: oversample=True, random_state=42, test_size=0.25, batch size=64
# DONE

# %%
# Uncomment to load model trained ahead of time
#learn = cnn_learner(dl, resnet18, pretrained=True, wd=2e-4, ps=0.8, 
#            metrics=[accuracy,F1Score(),Precision(),Recall(), RocAucBinary(),MatthewsCorrCoef()],
#            cbs=[ShowGraphCallback()])
#learn = learn.load('chembl1978-model')

# %%
learn = train_model(dl, epochs=10)
# Out:
# Training a model on the provided data
#
# ### Architecture: arch=<function resnet18 at 0x7f667016aaf0> ###
# 	 pretrained=True, epochs=10
#
# ### Regularization: weight decay=0.0002, droput rate=0.8 ###
#
# Finding a learning rate...
# Using the base learning rate lr=0.001737800776027143
#
# ### Training the model... ###
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.404802</td>
#       <td>0.173514</td>
#       <td>0.940281</td>
#       <td>0.734375</td>
#       <td>0.615721</td>
#       <td>0.909677</td>
#       <td>0.970542</td>
#       <td>0.719127</td>
#       <td>00:35</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.202499</td>
#       <td>0.149245</td>
#       <td>0.961944</td>
#       <td>0.810496</td>
#       <td>0.739362</td>
#       <td>0.896774</td>
#       <td>0.976586</td>
#       <td>0.794106</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.148916</td>
#       <td>0.160211</td>
#       <td>0.954918</td>
#       <td>0.787879</td>
#       <td>0.687500</td>
#       <td>0.922581</td>
#       <td>0.974883</td>
#       <td>0.773598</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.111467</td>
#       <td>0.183827</td>
#       <td>0.944965</td>
#       <td>0.756477</td>
#       <td>0.632035</td>
#       <td>0.941935</td>
#       <td>0.983491</td>
#       <td>0.745209</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.097799</td>
#       <td>0.131496</td>
#       <td>0.961944</td>
#       <td>0.813754</td>
#       <td>0.731959</td>
#       <td>0.916129</td>
#       <td>0.981177</td>
#       <td>0.799050</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.077026</td>
#       <td>0.106147</td>
#       <td>0.973653</td>
#       <td>0.864048</td>
#       <td>0.812500</td>
#       <td>0.922581</td>
#       <td>0.983464</td>
#       <td>0.851629</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.070779</td>
#       <td>0.093622</td>
#       <td>0.975995</td>
#       <td>0.875380</td>
#       <td>0.827586</td>
#       <td>0.929032</td>
#       <td>0.978942</td>
#       <td>0.863912</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.033297</td>
#       <td>0.110594</td>
#       <td>0.977166</td>
#       <td>0.877743</td>
#       <td>0.853659</td>
#       <td>0.903226</td>
#       <td>0.977889</td>
#       <td>0.865580</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.024566</td>
#       <td>0.107759</td>
#       <td>0.977752</td>
#       <td>0.879747</td>
#       <td>0.863354</td>
#       <td>0.896774</td>
#       <td>0.977891</td>
#       <td>0.867684</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.017726</td>
#       <td>0.116431</td>
#       <td>0.978923</td>
#       <td>0.885350</td>
#       <td>0.874214</td>
#       <td>0.896774</td>
#       <td>0.978038</td>
#       <td>0.873833</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.015307</td>
#       <td>0.114297</td>
#       <td>0.979508</td>
#       <td>0.886731</td>
#       <td>0.889610</td>
#       <td>0.883871</td>
#       <td>0.978192</td>
#       <td>0.875472</td>
#       <td>00:43</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Plotting the performance on the validation set using the given metrics is useful. Remember that its the metrics you care about the most (often/ideally you're optimizing a single metric). In our case, that could be the Matthew's correlation coefficient:

# %%
learn.recorder.plot_metrics()

# %%
#from IPython.display import display, Image
#display(Image(NB_DIR/'assets'/'molecules_training_output.png'))
#display(Image(NB_DIR/'assets'/'molecules_training_output2.png'))

# %%
#learn.save('chembl1978-model')
# Out:
# Path('models/chembl1978-model.pth')

# %% [markdown]
# ## Interpretation

# %% [markdown]
# Here are a few predictions and labels:

# %%
learn.show_results()

# %% [markdown]
# How many mistakes did the model make? Of what kind?

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# On what images was it the most wrong in terms of high confidence in wrong predictions?

# %%
interp.plot_top_losses(k=8)

# %% [markdown]
# In many cases, inspection of cases where the model was the most wrong can be extremely useful during model development.

# %% [markdown]
# ## Class activation maps

# %% [markdown]
# Using _class activation maps_ we can get an impression of what features the model used to make its predictions:

# %%
# !{sys.executable} -m pip install fastai_amalgam matplotlib_venn palettable
# Out:
# Requirement already satisfied: fastai_amalgam in /home/ubuntu/anaconda3/envs/pcs956/lib/python3.8/site-packages (0.0.26)
# Requirement already satisfied: matplotlib_venn in /home/ubuntu/anaconda3/envs/pcs956/lib/python3.8/site-packages (0.11.6)
# Collecting palettable
#   Downloading palettable-3.3.0-py2.py3-none-any.whl (111 kB)
#      |████████████████████████████████| 111 kB 3.8 MB/s eta 0:00:01
# Requirement already satisfied: scipy in /home/ubuntu/anaconda3/envs/pcs956/lib/python3.8/site-packages (from matplotlib_venn) (1.7.1)
# Requirement already satisfied: numpy in /home/ubuntu/anaconda3/envs/pcs956/lib/python3.8/site-packages (from matplotlib_venn) (1.21.2)
# Requirement already satisfied: matplotlib in /home/ubuntu/anaconda3/envs/pcs956/lib/python3.8/site-packages (from matplotlib_venn) (3.4.2)
# Requirement already satisfied: cycler>=0.10 in /home/ubuntu/anaconda3/envs/pcs956/lib/python3.8/site-packages (from matplotlib->matplotlib_venn) (0.10.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/ubuntu/anaconda3/envs/pcs956/lib/python3.8/site-packages (from matplotlib->matplotlib_venn) (8.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/ubuntu/anaconda3/envs/pcs956/lib/python3.8/site-packages (from matplotlib->matplotlib_venn) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /home/ubuntu/anaconda3/envs/pcs956/lib/python3.8/site-packages (from matplotlib->matplotlib_venn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/ubuntu/anaconda3/envs/pcs956/lib/python3.8/site-packages (from matplotlib->matplotlib_venn) (1.3.1)
# Requirement already satisfied: six in /home/ubuntu/anaconda3/envs/pcs956/lib/python3.8/site-packages (from cycler>=0.10->matplotlib->matplotlib_venn) (1.16.0)
# Installing collected packages: palettable
# Successfully installed palettable-3.3.0

# %%
import sys
sys.path.append("../")
from some_utils import get_mol_gradcam

# %%
img, c = dl.valid_ds[0]

# %%
img
# Out:
# PILImage mode=RGB size=500x500

# %%
get_mol_gradcam(dl.valid_ds[0], dl, learn)
# Out:
# /home/ubuntu/anaconda3/envs/pcs956/lib/python3.8/site-packages/torch/nn/modules/module.py:974: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "

# %% [markdown]
# Let's try a couple:

# %%
random.seed(2)
for instance in random.choices(dl.valid_ds, k=4):
    get_mol_gradcam(instance, dl, learn)
# Out:
# /home/ubuntu/anaconda3/envs/pcs956/lib/python3.8/site-packages/torch/nn/modules/module.py:974: UserWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   warnings.warn("Using a non-full backward hook when the forward contains multiple autograd Nodes "

# %% [markdown]
# The way the model seems to sometimes use information from outside the actual molecule is an indication that there is some _data leakage_ in the way the problem has been set up. I.e. that there's information in the images that relates to activity but that potentially isn't in the actual molecular structure.

# %% [markdown]
# # Extra: train models on all the data

# %% [markdown]
# We'll now train models for each of the seven data sets. This takes a while... You can skip this and load the outputs as plots below.

# %%
models = []
for data in ds: 
    name = str(data).split('/')[-1].split("_")[0]
    print(f"Training a resnet18 model on {name}")
    print(f"Top score in the paper was {top_mcc_scores[name]}")
    print()
          
    dl = get_dataloader(data, oversample=True, bs=64, batch_tfms=batch_tfms)
    learn = train_model(dl, epochs=10)
    models.append(learn)
    print("#"*40)
    print()
    learn.recorder.plot_metrics()
    print("#"*40)
    print()
    print()
# Out:
# Training a resnet18 model on CHEMBL1978
# Top score in the paper was 0.904
#
# Creating a dataloader for the dataset CHEMBL1978_cl
# Settings: oversample=True, random_state=42, test_size=0.25, batch size=64
# DONE
# Training a model on the provided data
#
# ### Architecture: arch=<function resnet18 at 0x7f2a648328b0> ###
# 	 pretrained=True, epochs=10
#
# ### Regularization: weight decay=0.0002, droput rate=0.8 ###
#
# Finding a learning rate...
# Using the base learning rate lr=0.0014454397605732083
#
# ### Training the model... ###
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.415683</td>
#       <td>0.318493</td>
#       <td>0.875878</td>
#       <td>0.579365</td>
#       <td>0.418338</td>
#       <td>0.941935</td>
#       <td>0.974335</td>
#       <td>0.577921</td>
#       <td>00:39</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.
td>
#       <td>00:49</td>
#     </tr>
#   </tbody>
# </table>
# ########################################
# ########################################

# %%
from IPython.display import display, Image

#for fn in sorted(list((NB_DIR/'assets'/'molecules_training').iterdir())):
#    display(Image(fn))

# %% [markdown]
# <img width=60% src="assets/MOESM-paper.png">

# %% [markdown]
# # Extra: Test the effect of varying the validation set

# %% [markdown]
# > How sensitive are the results to the specific random selection of validation data?
#
# If sensitive, one should do **k-fold cross-validation** rather than the hold-out validation above. At the cost of increased training time...

# %%
epochs=5
models = []
for random_state in [1,2,3,42]:
    print(f"Training a resnet18 model with random state {random_state} when sampling validation data. {epochs} epochs:")
    dl = get_dataloader(ds[0], oversample=False, random_state=random_state, test_size=0.2, bs=64, 
                        batch_tfms=None)
    learn = train_model(dl, epochs=epochs)
    models.append(learn)
    print("#"*40)
    print()
    learn.recorder.plot_metrics()
    print("#"*40)
    print()
    print()
# Out:
# Training a resnet18 model with random state 1 when sampling validation data. 5 epochs:
# Creating a dataloader for the dataset CHEMBL1978_cl
# Settings: oversample=False, random_state=1, test_size=0.2, batch size=64
# DONE
# Training a model on the provided data
#
# ### Architecture: arch=<function resnet18 at 0x7f2a648328b0> ###
# 	 pretrained=True, epochs=5
#
# ### Regularization: weight decay=0.0002, droput rate=0.8 ###
#
# Finding a learning rate...
# Using the base learning rate lr=0.007585775572806597
#
# ### Training the model... ###
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.485873</td>
#       <td>0.341405</td>
#       <td>0.869788</td>
#       <td>0.502793</td>
#       <td>0.384615</td>
#       <td>0.725806</td>
#       <td>0.885287</td>
#       <td>0.465075</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.274298</td>
#       <td>0.449157</td>
#       <td>0.926116</td>
#       <td>0.356688</td>
#       <td>0.848485</td>
#       <td>0.225806</td>
#       <td>0.906256</td>
#       <td>0.414994</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.269643</td>
#       <td>0.174503</td>
#       <td>0.937820</td>
#       <td>0.568528</td>
#       <td>0.767123</td>
#       <td>0.451613</td>
#       <td>0.954747</td>
#       <td>0.559408</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.224123</td>
#       <td>0.199998</td>
#       <td>0.937088</td>
#       <td>0.697183</td>
#       <td>0.618750</td>
#       <td>0.798387</td>
#       <td>0.949530</td>
#       <td>0.669415</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.130561</td>
#       <td>0.092070</td>
#       <td>0.967081</td>
#       <td>0.814815</td>
#       <td>0.831933</td>
#       <td>0.798387</td>
#       <td>0.985791</td>
#       <td>0.796961</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.079850</td>
#       <td>0.079960</td>
#       <td>0.970007</td>
#       <td>0.831276</td>
#       <td>0.848739</td>
#       <td>0.814516</td>
#       <td>0.988529</td>
#       <td>0.815032</td>
#       <td>00:25</td>
#     </tr>
#   </tbody>
# </table>
# ########################################
# ########################################
#
#
# Training a resnet18 model with random state 2 when sampling validation data. 5 epochs:
# Creating a dataloader for the dataset CHEMBL1978_cl
# Settings: oversample=False, random_state=2, test_size=0.2, batch size=64
# DONE
# Training a model on the provided data
#
# ### Architecture: arch=<function resnet18 at 0x7f2a648328b0> ###
# 	 pretrained=True, epochs=5
#
# ### Regularization: weight decay=0.0002, droput rate=0.8 ###
#
# Finding a learning rate...
# Using the base learning rate lr=0.009120108559727669
#
# ### Training the model... ###
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.484102</td>
#       <td>0.275456</td>
#       <td>0.924653</td>
#       <td>0.424581</td>
#       <td>0.690909</td>
#       <td>0.306452</td>
#       <td>0.855578</td>
#       <td>0.427890</td>
#       <td>00:21</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>precision_score</th>
#       <th>recall_score</th>
#       <th>roc_auc_score</th>
#       <th>matthews_corrcoef</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.266631</td>
#       <td>0.392111</td>
#       <td>0.929042</td>
#       <td>0.419162</td>
#       <td>0.813953</td>
#       <td>0.282258</td>
#       <td>0.849058</td>
#       <td>0.453834</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.263402</td>
#       <td>0.217283</td>
#       <td>0.934162</td>
#       <td>0.634146</td>
#       <td>0.639344</td>
#       <td>0.629032</td>
#       <td>0.931630</td>
#       <td>0.597999</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.192230</td>
#       <td>0.133517</td>
#       <td>0.959766</td>
#       <td>0.748858</td>
#       <td>0.863158</td>
#       <td>0.661290</td>
#       <td>0.964920</td>
#       <td>0.735038</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.120324</td>
#       <td>0.150278</td>
#       <td>0.959766</td>
#       <td>0.761905</td>
#       <td>0.822430</td>
#       <td>0.709677</td>
#       <td>0.962234</td>
#       <td>0.742461</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.